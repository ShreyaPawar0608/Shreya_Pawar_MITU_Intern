# %%
"""
Create a sample file with some text in it
""";

# %%
# open the file
f=open("Sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='Sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'Python is a high-level, interpreted programming language widely celebrated for its clear syntax, readability, and versatile application across data science, web development, automation, and artificial intelligence.\n'

# %%
f.readline()
# Out:
# 'Python is a high-level, general-purpose, interpreted programming language widely celebrated for its clear syntax and readability'

# %%
f.readline()
# Out:
# ''

# %%
f=open("Sample.txt")

# %%
f.readline(10)
# Out:
# 'Python is '

# %%
f.readline(5)
# Out:
# 'a hig'

# %%
f=open("Sample.txt")

# %%
data=f.readlines()

# %%
data
# Out:
# ['Python is a high-level, interpreted programming language widely celebrated for its clear syntax, readability, and versatile application across data science, web development, automation, and artificial intelligence.\n',
#  'Python is a high-level, general-purpose, interpreted programming language widely celebrated for its clear syntax and readability']

# %%
for line in data:
    print(line)
# Out:
# Python is a high-level, interpreted programming language widely celebrated for its clear syntax, readability, and versatile application across data science, web development, automation, and artificial intelligence.
#
# Python is a high-level, general-purpose, interpreted programming language widely celebrated for its clear syntax and readability

# %%
# convert the data to uppercase

# %%
for line in data:
    print(line.upper())
# Out:
# PYTHON IS A HIGH-LEVEL, INTERPRETED PROGRAMMING LANGUAGE WIDELY CELEBRATED FOR ITS CLEAR SYNTAX, READABILITY, AND VERSATILE APPLICATION ACROSS DATA SCIENCE, WEB DEVELOPMENT, AUTOMATION, AND ARTIFICIAL INTELLIGENCE.
#
# PYTHON IS A HIGH-LEVEL, GENERAL-PURPOSE, INTERPRETED PROGRAMMING LANGUAGE WIDELY CELEBRATED FOR ITS CLEAR SYNTAX AND READABILITY

# %%
# read

# %%
f=open("Sample.txt")

# %%
text=f.read()

# %%
text
# Out:
# 'Python is a high-level, interpreted programming language widely celebrated for its clear syntax, readability, and versatile application across data science, web development, automation, and artificial intelligence.\nPython is a high-level, general-purpose, interpreted programming language widely celebrated for its clear syntax and readability'

# %%
print(text)
# Out:
# Python is a high-level, interpreted programming language widely celebrated for its clear syntax, readability, and versatile application across data science, web development, automation, and artificial intelligence.
# Python is a high-level, general-purpose, interpreted programming language widely celebrated for its clear syntax and readability

# %%
text.split()
# Out:
# ['Python',
#  'is',
#  'a',
#  'high-level,',
#  'interpreted',
#  'programming',
#  'language',
#  'widely',
#  'celebrated',
#  'for',
#  'its',
#  'clear',
#  'syntax,',
#  'readability,',
#  'and',
#  'versatile',
#  'application',
#  'across',
#  'data',
#  'science,',
#  'web',
#  'development,',
#  'automation,',
#  'and',
#  'artificial',
#  'intelligence.',
#  'Python',
#  'is',
#  'a',
#  'high-level,',
#  'general-purpose,',
#  'interpreted',
#  'programming',
#  'language',
#  'widely',
#  'celebrated',
#  'for',
#  'its',
#  'clear',
#  'syntax',
#  'and',
#  'readability']

# %%
f=open("Marathi.txt",encoding='utf-8')

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='Marathi.txt' mode='r' encoding='utf-8'>

# %%
print(f.read())
# Out:
# मराठी भाषा ही इंडो-युरोपीय भाषाकुळातील एक भाषा आहे. मराठी ही भारताच्या २२ अधिकृत भाषांपैकी एक आहे.
# मराठी महाराष्ट्र राज्याची अधिकृत, तर गोवा राज्याची सह-अधिकृत भाषा आहे. २०११ च्या जनगणनेनुसार, भारतात मराठी भाषकांची एकूण लोकसंख्या सुमारे १४ कोटी आहे.
# मराठी मातृभाषा असणाऱ्या लोकांच्या संख्येनुसार मराठी ही जगातील १०वी व भारतातील ३री भाषा आहे.
# मराठी भाषा भारताच्या प्राचीन भाषांपैकी एक असून, महाराष्ट्री प्राकृतचे आधुनिक रूप आहे.

# %%
f.close()

# %%
f.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 f.readable()
#
# ValueError: I/O operation on closed file

# %%
# writing in a file

# %%
f=open("Sample.txt",'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=['frodo took the ring','he started his journey to mount doom']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines

# %%
# write

# %%
sent = 'frodo took the ring, he started his journey to mount doom'

# %%
f=open("Sample.txt",'w')
f.write(sent)
f.close()

# %%
with open('myfile.txt','w') as f:
    f.write("This is first line\n")
    f.write("This is second\n")
    f.write("This is third")

# %%
s=open("Sample.txt",'r')
f=open("myfile.txt",'w')

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s=open("Sample.text",'a')

# %%
s.write("\nDone")
# Out:
# 5

# %%
s.close()

# %%
s.tell()
# Out:
# 24

# %%
s.seek(10)
# Out:
# 10
