# %%
"""
Create a class called Student
Create 2-3 objects having attributes name,age

Create a method which will add a skill (eg...Python, ML, Java) to the student
where you can view the info of it later(i.e. skills learned by a student).
"""
# Out:
# '\nCreate a class called Student\nCreate 2-3 objects having attributes name,age\n\nCreate a method which will add a skill (eg...Python, ML, Java) to the student\nwhere you can view the info of it later(i.e. skills learned by a student).\n'

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        self.skill=[]
    def add_skill(self,skill):
        self.skill.append(skill)
    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Skills learned by student: {self.skill}")

# %%
s1=Student("Shreya",17)
s2=Student("Amit",20)

# %%
s1.add_skill('Python')

# %%
s1.display_info()
# Out:
# Name: Shreya
# Age: 17
# Skills learned by student: ['Python']

# %%
s2.add_skill("Java")

# %%
s2.display_info()
# Out:
# Name: Amit
# Age: 20
# Skills learned by student: ['Java']

# %%
s2.add_skill("ML")

# %%
s2.display_info()
# Out:
# Name: Amit
# Age: 20
# Skills learned by student: ['Java', 'ML']

# %%
s3=Student("Shivani",23)

# %%
s3.display_info()
# Out:
# Name: Shivani
# Age: 23
# Skills learned by student: []

# %%
# Inheritance

# %%
class Person:
    insti="MITU"
    def __init__(self,age,ht):
        self.age=age
        self.ht=ht
    def show(self):
        print(f"Age -> {self.age}, Height -> {self.ht},Institute -> {self.insti}")

# %%
class Ravi(Person):
    def __init__(self,age,ht,sal):
        super().__init__(age,ht)
        self.sal=sal
    def show_sal(self):
        print(f"Salary is {self.sal}")

# %%
a=Ravi(29,5.9,5600)

# %%
a.show_sal()
# Out:
# Salary is 5600

# %%
a.show()
# Out:
# Age -> 29, Height -> 5.9,Institute -> MITU

# %%
# Polymorphism

# %%
class Animal:
    def speak(self):
        return "Sound of an animal"

# %%
class Dog:
    def speak(self):
        return "woof!!!"

class Cat:
    def speak(self):
        return "meow!!!"

# %%
d=Dog()
c=Cat()

# %%
d.speak()
# Out:
# 'woof!!!'

# %%
c.speak()
# Out:
# 'meow!!!'

# %%
# Simple menu driven app with oop

# %%
class Menuapp:
    def __init__(self):
        self.item_list = []

    def show_menu(self):
        print("\nMenu")
        print("1. Add Items")
        print("2. View Items")
        print("3. Exit")

    def add_items(self):
        item = input("Enter item name: ")
        self.item_list.append(item)

    def view_items(self):
        print("Items:", self.item_list)

    def run(self):
        while True:
            self.show_menu()
            ch = int(input("Enter the choice: "))

            if ch == 1:
                self.add_items()

            elif ch == 2:
                self.view_items()

            elif ch == 3:
                print("Exiting...")
                break

            else:
                print("Invalid choice")


obj = Menuapp()
obj.run()
# Out:
# Menu
# 1. Add Items
# 2. View Items
# 3. Exit
# Enter the choice:  1
# Enter item name:  Pen
# Menu
# 1. Add Items
# 2. View Items
# 3. Exit
# Enter the choice:  1
# Enter item name:  App
# Menu
# 1. Add Items
# 2. View Items
# 3. Exit
# Enter the choice:  2
# Items: ['Pen', 'App']
#
# Menu
# 1. Add Items
# 2. View Items
# 3. Exit
# Enter the choice:  3
# Exiting...

# %%
# Encapsulation with getter and setter

# %%
class Person:
    def __init__(self,name,age):
        self.__age=age
        self.__name=name

    #getter
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    #setter
    def set_age(self,age):
        self.__age=age

# %%
p=Person('Arun',34)

# %%
p.get_name()
# Out:
# 'Arun'

# %%
p.get_age()
# Out:
# 34

# %%
p.set_age(32)

# %%
p.get_age()
# Out:
# 32

# %%
# dunder methods/magic methods

# %%
dir(p)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'get_age',
#  'get_name',
#  'name',
#  'set_age']

# %%
class Person:
    def __init__(self,name,age):
        self.__age=age
        self.__name=name

    #getter
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    #setter
    def set_age(self,age):
        self.__age=age

    def __str__(self):
        return f"age -> {self.__age}, name -> {self.__name}"

# %%
p=Person('Arun',34)

# %%
print(p)
# Out:
# age -> 34, name -> Arun
