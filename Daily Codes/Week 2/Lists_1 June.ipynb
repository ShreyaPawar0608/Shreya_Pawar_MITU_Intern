# %%
l=[12,34,56,78]

# %%
print(l)
# Out:
# [12, 34, 56, 78]

# %%
l1=[12,34,56,"Python","Java",1.34]

# %%
print(l1)
# Out:
# [12, 34, 56, 'Python', 'Java', 1.34]

# %%
#lists are ordered

# %%
l1
# Out:
# [12, 34, 56, 'Python', 'Java', 1.34]

# %%
l1[2]
# Out:
# 56

# %%
l1[-3]
# Out:
# 'Python'

# %%
#lists are mutable

# %%
l1[1]
# Out:
# 34

# %%
l1[1]=100

# %%
print(l1)
# Out:
# [12, 100, 56, 'Python', 'Java', 1.34]

# %%
l1[-2]
# Out:
# 'Java'

# %%
l1[-2]=True

# %%
print(l1)
# Out:
# [12, 100, 56, 'Python', True, 1.34]

# %%
#list slicing

# %%
l2=[21,23,45,67,89,11]

# %%
l2
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l2[1:4]
# Out:
# [23, 45, 67]

# %%
l2[1:-2]
# Out:
# [23, 45, 67]

# %%
l2[0:6:2]
# Out:
# [21, 45, 89]

# %%
l2[::2]
# Out:
# [21, 45, 89]

# %%
l2[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l2[1:4]=100,200,300

# %%
l2
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2=[21,100,200,300,89,11]

# %%
89 in l2
# Out:
# True

# %%
1038 in l2
# Out:
# False

# %%
#arithmetic operations

# %%
'ok'*3 #
# Out:
# 'okokok'

# %%
l2*2 #repetition of list
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l2+[60,70,80] #concatination of list
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
l3=[12,34,56]

# %%
l3
# Out:
# [12, 34, 56]

# %%
l4=[33,65,90]

# %%
l4
# Out:
# [33, 65, 90]

# %%
l3+l4 #Adding two different lists
# Out:
# [12, 34, 56, 33, 65, 90]

# %%
# iteration over list and print square of the elements

# %%
for i in l2:
    print(i**2,end=" ")
# Out:
# 441 10000 40000 90000 7921 121

# %%
#print odd numbers in list

# %%
for i in l2:
    if i%2==1:
        print(i,end=' ')
# Out:
# 21 89 11

# %%
#list comprehension

# %%
newl=[i**2 for i in l2]

# %%
print(newl)
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
newl1=[i for i in l2 if i%2==1]

# %%
print(newl1)
# Out:
# [21, 89, 11]

# %%
names=['Shreya','Sukanya','Aditi','samruddhi','aryan']

# %%
names
# Out:
# ['Shreya', 'Sukanya', 'Aditi', 'samruddhi', 'aryan']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# Shreya
# Sukanya
# samruddhi

# %%
new=[i for i in names if i.lower().startswith('s')]

# %%
new
# Out:
# ['Shreya', 'Sukanya', 'samruddhi']

# %%
l2
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
len(l2)
# Out:
# 6

# %%
max(l2)
# Out:
# 300

# %%
min(l2)
# Out:
# 11

# %%
sorted(l2, reverse=True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
l2.append(10000)

# %%
l2
# Out:
# [21, 100, 200, 300, 89, 11, 10000]

# %%
l1=[1,2,3]
l2=[1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1,l2
# Out:
# ([1, 2, 3, [100, 200]], [1, 2, 3, 100, 200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=65

# %%
l1
# Out:
# [1, 2, 3, [100, 65]]

# %%
l=[21,100,200,300,89,11]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.index(89)
# Out:
# 4

# %%
l.sort(reverse=True,end" ")
# Out:
#   Cell In[4], line 1
#     l.sort(reverse=True,end" ")
#                               ^
# SyntaxError: positional argument follows keyword argument
