# %%
print('Hello World')
# Out:
# Hello World

# %%
#add above -> A,  below -> B   del-> x

# %% [markdown]
# # ID

# %%
num=56

# %%
num1=8

# %%
name='riya'

# %%
Pass = 28

# %%
Pass = 3

# %%
Pass
# Out:
# 3

# %%
name
# Out:
# 'riya'

# %%
a=10
b=0.4
c="Shreya"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %% [markdown]
# #float

# %%
num=1234567890 ** 234
num
# Out:
# ...

# %%
num = 23e4

# %%
num
# Out:
# 230000.0

# %%
type(num)
# Out:
# float

# %%
#String

# %%
sent=,

# %%
num1=int(input("Enter first number:"));
num2=int(input("Enter second number:"));
res=num1+num2;
print(res);
# Out:
# Enter first number: 5454
# Enter second number: 87878
# 93332
